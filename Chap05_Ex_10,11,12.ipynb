# %% [markdown]
# <a href="https://colab.research.google.com/github/23005/EU_M_Math/blob/main/Chap05_Ex_10%2C11%2C12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline

# %%
x = np.linspace(0, 10, num=11, endpoint=True)
y = np.sin(x**2/5.0)
plt.plot(x,y,'o')
plt.grid(True)

# %%
#Ex-10
from scipy import interpolate

f = interpolate.interp1d(x, y, 'linear')
plt.plot(x,f(x),'-')
plt.grid(True)

# %%
#Ex-11
f2 = interpolate.interp1d(x, y, 'quadratic')
xnew = np.linspace(0, 10, num=30, endpoint=True)
plt.plot(x, y, 'o', xnew, f(xnew), '-', xnew, f2(xnew), '--')
plt.legend(['data', 'liner', 'quadratic'], loc='best')
plt.grid(True)

# %%
#Ex-12
f3 = interpolate.interp1d(x, y, 'cubic')
plt.plot(x, y, 'o', xnew, f(xnew), '-', xnew, f2(xnew), '--', xnew, f3(xnew), '-.')
plt.legend(['data', 'liner', 'quadratic', 'cubic'], loc='best')
plt.grid(True)
