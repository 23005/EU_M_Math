# %% [markdown]
# <a href="https://colab.research.google.com/github/23005/EU_M_Math/blob/main/Chap06_Cm_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from pandas import Series,DataFrame

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
sns.set()
# %matplotlib inline

# %%
import requests,zipfile
from io import StringIO
import io

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00356/student.zip'
r = requests.get(url, stream=True)
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall()

# %%
student_data_math = pd.read_csv('student-mat.csv', sep=';')

# %%
#Cm6-1
G1mean = student_data_math.groupby(['age','sex'])['G1'].mean()
G1mean.unstack()
# Out:
# sex          F          M
# age
# 15   10.052632  12.250000
# 16   10.203704  11.740000
# 17   11.103448  10.600000
# 18   10.883721  10.538462
# 19   10.642857   9.700000
# 20   15.000000  13.000000
# 21         NaN  10.000000
# 22         NaN   6.000000

# %%
#Cm6-2
G1mean.unstack().dropna()
# Out:
# sex          F          M
# age
# 15   10.052632  12.250000
# 16   10.203704  11.740000
# 17   11.103448  10.600000
# 18   10.883721  10.538462
# 19   10.642857   9.700000
# 20   15.000000  13.000000
